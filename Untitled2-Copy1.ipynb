# %%
num = int(input("Enter the number: "))

print("Multiplication Table of", num)
for i in range(1, 11):
   print(num,"X",i,"=",num * i)
# Out:
# Enter the number: 5
# Multiplication Table of 5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
num = int(input("Enter the number: "))

print("Multiplication Table of", num)
for i in range(1, 11):
   print(num,"X",i,"=",num * i)
# Out:
# Enter the number: 10
# Multiplication Table of 10
# 10 X 1 = 10
# 10 X 2 = 20
# 10 X 3 = 30
# 10 X 4 = 40
# 10 X 5 = 50
# 10 X 6 = 60
# 10 X 7 = 70
# 10 X 8 = 80
# 10 X 9 = 90
# 10 X 10 = 100

# %%
num = int(input("Enter the number: "))

print("Multiplication Table of", num)
for i in range(1, 11):
   print(num,"X",i,"=",num * i)
# Out:
# Enter the number: 2.2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d8a5732f6e51> in <module>
# ----> 1 num = int(input("Enter the number: "))
#       2
#       3 print("Multiplication Table of", num)
#       4 for i in range(1, 11):
#       5    print(num,"X",i,"=",num * i)
#
# ValueError: invalid literal for int() with base 10: '2.2'

# %%
num = int(input("Enter the number: "))

print("Multiplication Table of", num)
for i in range(1, 11):
   print(num,"X",i,"=",num * i)
# Out:
# Enter the number: 11
# Multiplication Table of 11
# 11 X 1 = 11
# 11 X 2 = 22
# 11 X 3 = 33
# 11 X 4 = 44
# 11 X 5 = 55
# 11 X 6 = 66
# 11 X 7 = 77
# 11 X 8 = 88
# 11 X 9 = 99
# 11 X 10 = 110

# %%
num = int(input("Enter the value of n: "))
hold = num
sum = 0

if num <= 0: 
   print("Enter a whole positive number!") 
else: 
   while num > 0:
        sum = sum + num
        num = num - 1;
    # displaying output
    print("Sum of first", hold, "natural numbers is: ", sum)
# Out:
#   File "<tokenize>", line 12
#     print("Sum of first", hold, "natural numbers is: ", sum)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
num = int(input("Enter the value of n: "))
hold = num
sum = 0

if num <= 0: 
   print("Enter a whole positive number!") 
else: 
   while num > 0:
        sum = sum + num
        num = num - 1;
    # displaying output
print("Sum of first", hold, "natural numbers is: ", sum)
# Out:
# Enter the value of n: 30
# Sum of first 30 natural numbers is:  465

# %%
imatplotlib notebook
import pandas as pd

# %%
pd.series([8,7,2,8,9]).hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9954f0295ff5> in <module>
# ----> 1 pd.series([8,7,2,8,9]).hist()
#
# NameError: name 'pd' is not defined

# %%
matplotlib notebook
import pandas as pd

# %%
pd.series([8,7,2,8,9]).hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9954f0295ff5> in <module>
# ----> 1 pd.series([8,7,2,8,9]).hist()
#
# NameError: name 'pd' is not defined

# %%
# %matplotlib notebook
import pandas as pd

# %%
pd.Series([8,7,2,8,9]).hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-12c5399d38b7> in <module>
# ----> 1 pd.Series([8,7,2,8,9]).hist()
#
# NameError: name 'pd' is not defined

# %%
pd.Series([8,7,2,8,9]).hist()

# %%
pd.Series([8,7,2,8,9]).hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import pandas as pd

# %%
pd.Series([8,8,2,8,9,9,9,9,9,9]).hist()
# Out:
# <img src="data:image/png;base64,..." width="640">
